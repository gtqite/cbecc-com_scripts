# %%
from lxml import etree as ET
import pandas as pd

# Presidio Knolls 100CD_No ERV
# SRJC STEM Building Title 24

file = ('SRJC STEM Building Title 24.cibd16x')
filename = file.split('.')[0]

tree = ET.parse(file)
root = tree.getroot()

# %%
space_list = []

for space in root.iter('Spc'):
    spc = {}
    
    # General Room info
    spc['Space Name'] = space.find('Name').text
    try:
        spc['Conditioning'] = space.find('CondgType').text
    except:
        spc['Conditioning'] = 'DirectlyConditioned'
    spc['Thermal Zone'] = space.find('ThrmlZnRef').text
    spc['Function'] = space.find('SpcFunc').text
    spc['Story'] = space.getparent().find('Name').text
    spc['SHW Ref'] = space.find('SHWFluidSegRef').text
    
    # Ventilation info
    try:
        spc['Vent per Person'] = float(space.find('VentPerPerson').text)
    except:
        spc['Vent per Person'] = '- default -'
    try:
        spc['Vent per Area'] = float(space.find('VentPerArea').text)
    except:
        spc['Vent per Area'] = '- default -'
    try:
        spc['Vent ACH'] = float(space.find('VentACH').text)
    except:
        spc['Vent ACH'] = '- default -'
    try:
        spc['Vent per Space'] = float(space.find('VentPerSpc').text)
    except:
        spc['Vent per Space'] = '- default -'
    try:
        spc['Exh per Area'] = float(space.find('ExhPerArea').text)
    except:
        spc['Exh per Area'] = '- default -'
    try:
        spc['Exh ACH'] = float(space.find('ExhACH').text)
    except:
        spc['Exh ACH'] = '- default -'
    try:
        spc['Exh per Space'] = float(space.find('ExhPerSpc').text)
    except:
        spc['Exh per Space'] = '- default -'    

    # Lighting and Equipment
    try:
        spc['Equipment Power Density'] = float(space.find('RecptPwrDens').text)
    except:
        spc['Equipment Power Density'] = '- default -'
    try:
        spc['Lighting Power Density'] = float(space.find('IntLPDReg').text)
    except:
        if space.find('IntLtgSys') is not None:
            spc['Lighting System Name'] = space.find('IntLtgSys/Name').text
            for i in range(5):
                try:
                    spc['Luminaire{}'.format(i+1)] = space.find('IntLtgSys/LumRef[@index="{}"]'.format(i)).text
                except:
                    spc['Luminaire{}'.format(i+1)] = None
                try:
                    spc['Luminaire{} Count'.format(i+1)] = float(space.find('IntLtgSys/LumCnt[@index="{}"]'.format(i)).text)
                except:
                    spc['Luminaire{} Count'.format(i+1)] = None
        else:
            spc['Lighting Power Density'] = '- default -'
    

    
    space_list.append(spc)

spc_header = [
    'Space Name', 'Conditioning', 'Thermal Zone', 'Function', 'Story','SHW Ref', 
    'Vent per Person', 'Vent per Area', 'Vent ACH', 'Vent per Space', 'Exh per Area', 'Exh ACH', 'Exh per Space', 
    'Equipment Power Density', 'Lighting Power Density', 
    'Lighting System Name', 'Luminaire1', 'Luminaire1 Count', 'Luminaire2', 'Luminaire2 Count', 'Luminaire3', 'Luminaire3 Count', 'Luminaire4', 'Luminaire4 Count', 'Luminaire5', 'Luminaire5 Count']

space_df = pd.DataFrame(space_list, columns=spc_header)
space_df
# Out:
#                  Space Name           Conditioning            Thermal Zone  \
# 0                   FCU-1-1    DirectlyConditioned            FCU 1-1 Zone
# 1                   FCU-1-2    DirectlyConditioned            FCU 1-2 Zone
# 2                   FCU-1-3    DirectlyConditioned            FCU 1-3 Zone
# 3                   FCU-1-4    DirectlyConditioned            FCU 1-4 Zone
# 4                   FCU-1-5    DirectlyConditioned            FCU 1-5 Zone
# 5                   FCU-1-6    DirectlyConditioned            FCU 1-6 Zone
# 6                   LSV-101    DirectlyConditioned          LSV 101-1 Zone
# 7      UNCONDITION-1STFLOOR  IndirectlyConditioned  UNCONDITIONED_1STFLOOR
# 8                   VAV-101    DirectlyConditioned            VAV 101 Zone
# 9                   VAV-102    DirectlyConditioned            VAV 102 Zone
# 10                  VAV-103    DirectlyConditioned            VAV 103 Zone
# 11                  VAV-104    DirectlyConditioned            VAV 104 Zone
# 12                  VAV-105    DirectlyConditioned            VAV 105 Zone
# 13                  VAV-106    DirectlyConditioned            VAV 106 Zone
# 14                  VAV-107    DirectlyConditioned            VAV 107 Zone
# 15                  VAV-108    DirectlyConditioned            VAV 108 Zone
# 16                  VAV-109    DirectlyConditioned            VAV 109 Zone
# 17          VAV-110-111-112    DirectlyConditioned    VAV 110 111 112 Zone
# 18                  VAV-113    DirectlyConditioned            VAV 113 Zone
# 19                  VAV-114    DirectlyConditioned            VAV 114 Zone
# 20                  VAV-115    DirectlyConditioned            VAV 115 Zone
# 21                  VAV-116    DirectlyConditioned            VAV 116 Zone
# 22                  VAV-117    DirectlyConditioned            VAV 117 Zone
# 23                  VAV-118    DirectlyConditioned            VAV 118 Zone
# 24                  VAV-119    DirectlyConditioned            VAV 119 Zone
# 25                  VAV-120    DirectlyConditioned            VAV 120 Zone
# 26                  VAV-121    DirectlyConditioned            VAV 121 Zone
# 27                  VAV-122    DirectlyConditioned            VAV 122 Zone
# 28                  VAV-123    DirectlyConditioned            VAV 123 Zone
# 29                  VAV-124    DirectlyConditioned            VAV 124 Zone
# ..                      ...                    ...                     ...
# 73                  FCU-3-2    DirectlyConditioned            FCU 3-2 Zone
# 74                  LSV-301    DirectlyConditioned            LSV 301 Zone
# 75                  LSV-302    DirectlyConditioned            LSV 302 Zone
# 76                  LSV-303    DirectlyConditioned            LSV 303 Zone
# 77                  LSV-304    DirectlyConditioned            LSV 304 Zone
# 78                  LSV-305    DirectlyConditioned            LSV 305 Zone
# 79                  LSV-306    DirectlyConditioned            LSV 306 Zone
# 80                  LSV-307    DirectlyConditioned            LSV 307 Zone
# 81                  LSV-308    DirectlyConditioned            LSV 308 Zone
# 82   UNCONDITIONED-3RDFLOOR  IndirectlyConditioned  UNCONDITIONED_3RDFLOOR
# 83                  VAV-301    DirectlyConditioned            VAV 301 Zone
# 84                  VAV-302    DirectlyConditioned            VAV 302 Zone
# 85                  VAV-303    DirectlyConditioned            VAV 303 Zone
# 86                  VAV-304    DirectlyConditioned            VAV 304 Zone
# 87                  VAV-305    DirectlyConditioned            VAV 305 Zone
# 88                  VAV-306    DirectlyConditioned            VAV 306 Zone
# 89                  VAV-307    DirectlyConditioned            VAV 307 Zone
# 90                  VAV-308    DirectlyConditioned            VAV 308 Zone
# 91                  VAV-309    DirectlyConditioned            VAV 309 Zone
# 92                  VAV-310    DirectlyConditioned            VAV 310 Zone
# 93                  VAV-311    DirectlyConditioned            VAV 311 Zone
# 94                  VAV-312    DirectlyConditioned            VAV 312 Zone
# 95                  VAV-313    DirectlyConditioned            VAV 313 Zone
# 96                  VAV-314    DirectlyConditioned            VAV 314 Zone
# 97              VAV-315-317    DirectlyConditioned        VAV 315 317 Zone
# 98                  VAV-316    DirectlyConditioned            VAV 316 Zone
# 99              VAV-318-319    DirectlyConditioned        VAV 318 319 Zone
# 100                 VAV-320    DirectlyConditioned            VAV 320 Zone
# 101                 VAV-321    DirectlyConditioned            VAV 321 Zone
# 102                 VAV-322    DirectlyConditioned            VAV 322 Zone
#
#                                               Function             Story  \
# 0              Electrical, Mechanical, Telephone Rooms  Building Story 1
# 1              Electrical, Mechanical, Telephone Rooms  Building Story 1
# 2              Electrical, Mechanical, Telephone Rooms  Building Story 1
# 3              Electrical, Mechanical, Telephone Rooms  Building Story 1
# 4              Electrical, Mechanical, Telephone Rooms  Building Story 1
# 5              Electrical, Mechanical, Telephone Rooms  Building Story 1
# 6                               Laboratory, Scientific  Building Story 1
# 7             Unoccupied-Exclude from Gross Floor Area  Building Story 1
# 8      Corridors, Restrooms, Stairs, and Support Areas  Building Story 1
# 9    Office (Greater than 250 square feet in floor ...  Building Story 1
# 10     Corridors, Restrooms, Stairs, and Support Areas  Building Story 1
# 11                              Laboratory, Scientific  Building Story 1
# 12                              Laboratory, Scientific  Building Story 1
# 13     Corridors, Restrooms, Stairs, and Support Areas  Building Story 1
# 14     Corridors, Restrooms, Stairs, and Support Areas  Building Story 1
# 15   Convention, Conference, Multipurpose and Meeti...  Building Story 1
# 16     Corridors, Restrooms, Stairs, and Support Areas  Building Story 1
# 17     Classrooms, Lecture, Training, Vocational Areas  Building Story 1
# 18                              Laboratory, Scientific  Building Story 1
# 19                              Laboratory, Scientific  Building Story 1
# 20   Convention, Conference, Multipurpose and Meeti...  Building Story 1
# 21   Convention, Conference, Multipurpose and Meeti...  Building Story 1
# 22   Convention, Conference, Multipurpose and Meeti...  Building Story 1
# 23   Convention, Conference, Multipurpose and Meeti...  Building Story 1
# 24      Office (250 square feet in floor area or less)  Building Story 1
# 25      Office (250 square feet in floor area or less)  Building Story 1
# 26      Office (250 square feet in floor area or less)  Building Story 1
# 27     Corridors, Restrooms, Stairs, and Support Areas  Building Story 1
# 28     Classrooms, Lecture, Training, Vocational Areas  Building Story 1
# 29     Corridors, Restrooms, Stairs, and Support Areas  Building Story 1
# ..                                                 ...               ...
# 73             Electrical, Mechanical, Telephone Rooms  Building Story 3
# 74                              Laboratory, Scientific  Building Story 3
# 75                              Laboratory, Scientific  Building Story 3
# 76                              Laboratory, Scientific  Building Story 3
# 77     Classrooms, Lecture, Training, Vocational Areas  Building Story 3
# 78     Classrooms, Lecture, Training, Vocational Areas  Building Story 3
# 79                              Laboratory, Scientific  Building Story 3
# 80                              Laboratory, Scientific  Building Story 3
# 81                              Laboratory, Scientific  Building Story 3
# 82            Unoccupied-Exclude from Gross Floor Area  Building Story 3
# 83     Corridors, Restrooms, Stairs, and Support Areas  Building Story 3
# 84     Classrooms, Lecture, Training, Vocational Areas  Building Story 3
# 85     Classrooms, Lecture, Training, Vocational Areas  Building Story 3
# 86     Classrooms, Lecture, Training, Vocational Areas  Building Story 3
# 87   Office (Greater than 250 square feet in floor ...  Building Story 3
# 88   Convention, Conference, Multipurpose and Meeti...  Building Story 3
# 89   Convention, Conference, Multipurpose and Meeti...  Building Story 3
# 90   Office (Greater than 250 square feet in floor ...  Building Story 3
# 91     Corridors, Restrooms, Stairs, and Support Areas  Building Story 3
# 92   Convention, Conference, Multipurpose and Meeti...  Building Story 3
# 93     Corridors, Restrooms, Stairs, and Support Areas  Building Story 3
# 94     Corridors, Restrooms, Stairs, and Support Areas  Building Story 3
# 95   Office (Greater than 250 square feet in floor ...  Building Story 3
# 96     Corridors, Restrooms, Stairs, and Support Areas  Building Story 3
# 97     Classrooms, Lecture, Training, Vocational Areas  Building Story 3
# 98                              Laboratory, Scientific  Building Story 3
# 99     Classrooms, Lecture, Training, Vocational Areas  Building Story 3
# 100    Corridors, Restrooms, Stairs, and Support Areas  Building Story 3
# 101  Office (Greater than 250 square feet in floor ...  Building Story 3
# 102    Corridors, Restrooms, Stairs, and Support Areas  Building Story 3
#
#     SHW Ref Vent per Person Vent per Area     Vent ACH Vent per Space  ...  \
# 0      SHWS     - default -   - default -  - default -    - default -  ...
# 1      SHWS     - default -   - default -  - default -    - default -  ...
# 2      SHWS     - default -   - default -  - default -    - default -  ...
# 3      SHWS     - default -   - default -  - default -    - default -  ...
# 4      SHWS     - default -   - default -  - default -    - default -  ...
# 5      SHWS     - default -   - default -  - default -    - default -  ...
# 6      SHWS     - default -   - default -  - default -    - default -  ...
# 7      SHWS     - default -   - default -  - default -    - default -  ...
# 8      SHWS     - default -   - default -  - default -    - default -  ...
# 9      SHWS     - default -   - default -  - default -    - default -  ...
# 10     SHWS     - default -   - default -  - default -    - default -  ...
# 11     SHWS     - default -   - default -  - default -    - default -  ...
# 12     SHWS     - default -   - default -  - default -    - default -  ...
# 13     SHWS     - default -   - default -  - default -    - default -  ...
# 14     SHWS     - default -   - default -  - default -    - default -  ...
# 15     SHWS     - default -   - default -  - default -    - default -  ...
# 16     SHWS     - default -   - default -  - default -    - default -  ...
# 17     SHWS     - default -   - default -  - default -    - default -  ...
# 18     SHWS     - default -   - default -  - default -    - default -  ...
# 19     SHWS     - default -   - default -  - default -    - default -  ...
# 20     SHWS     - default -   - default -  - default -    - default -  ...
# 21     SHWS     - default -   - default -  - default -    - default -  ...
# 22     SHWS     - default -   - default -  - default -    - default -  ...
# 23     SHWS     - default -   - default -  - default -    - default -  ...
# 24     SHWS     - default -   - default -  - default -    - default -  ...
# 25     SHWS     - default -   - default -  - default -    - default -  ...
# 26     SHWS     - default -   - default -  - default -    - default -  ...
# 27     SHWS     - default -   - default -  - default -    - default -  ...
# 28     SHWS     - default -   - default -  - default -    - default -  ...
# 29     SHWS     - default -   - default -  - default -    - default -  ...
# ..      ...             ...           ...          ...            ...  ...
# 73     SHWS     - default -   - default -  - default -    - default -  ...
# 74     SHWS     - default -   - default -  - default -    - default -  ...
# 75     SHWS     - default -   - default -  - default -    - default -  ...
# 76     SHWS     - default -   - default -  - default -    - default -  ...
# 77     SHWS     - default -   - default -  - default -    - default -  ...
# 78     SHWS     - default -   - default -  - default -    - default -  ...
# 79     SHWS     - default -   - default -  - default -    - default -  ...
# 80     SHWS     - default -   - default -  - default -    - default -  ...
# 81     SHWS     - default -   - default -  - default -    - default -  ...
# 82     SHWS     - default -   - default -  - default -    - default -  ...
# 83     SHWS     - default -   - default -  - default -    - default -  ...
# 84     SHWS     - default -   - default -  - default -    - default -  ...
# 85     SHWS     - default -   - default -  - default -    - default -  ...
# 86     SHWS     - default -   - default -  - default -    - default -  ...
# 87     SHWS     - default -   - default -  - default -    - default -  ...
# 88     SHWS     - default -   - default -  - default -    - default -  ...
# 89     SHWS     - default -   - default -  - default -    - default -  ...
# 90     SHWS     - default -   - default -  - default -    - default -  ...
# 91     SHWS     - default -   - default -  - default -    - default -  ...
# 92     SHWS     - default -   - default -  - default -    - default -  ...
# 93     SHWS     - default -   - default -  - default -    - default -  ...
# 94     SHWS     - default -   - default -  - default -    - default -  ...
# 95     SHWS     - default -   - default -  - default -    - default -  ...
# 96     SHWS     - default -   - default -  - default -    - default -  ...
# 97     SHWS     - default -   - default -  - default -    - default -  ...
# 98     SHWS     - default -   - default -  - default -    - default -  ...
# 99     SHWS     - default -   - default -  - default -    - default -  ...
# 100    SHWS     - default -   - default -  - default -    - default -  ...
# 101    SHWS     - default -   - default -  - default -    - default -  ...
# 102    SHWS     - default -   - default -  - default -    - default -  ...
#
#     Luminaire1 Luminaire1 Count Luminaire2 Luminaire2 Count  Luminaire3  \
# 0          NaN              NaN        NaN              NaN         NaN
# 1          NaN              NaN        NaN              NaN         NaN
# 2          NaN              NaN        NaN              NaN         NaN
# 3          NaN              NaN        NaN              NaN         NaN
# 4          NaN              NaN        NaN              NaN         NaN
# 5          NaN              NaN        NaN              NaN         NaN
# 6          NaN              NaN        NaN              NaN         NaN
# 7          NaN              NaN        NaN              NaN         NaN
# 8          NaN              NaN        NaN              NaN         NaN
# 9          NaN              NaN        NaN              NaN         NaN
# 10         NaN              NaN        NaN              NaN         NaN
# 11         NaN              NaN        NaN              NaN         NaN
# 12         NaN              NaN        NaN              NaN         NaN
# 13         NaN              NaN        NaN              NaN         NaN
# 14         NaN              NaN        NaN              NaN         NaN
# 15         NaN              NaN        NaN              NaN         NaN
# 16         NaN              NaN        NaN              NaN         NaN
# 17         NaN              NaN        NaN              NaN         NaN
# 18         NaN              NaN        NaN              NaN         NaN
# 19         NaN              NaN        NaN              NaN         NaN
# 20         NaN              NaN        NaN              NaN         NaN
# 21         NaN              NaN        NaN              NaN         NaN
# 22         NaN              NaN        NaN              NaN         NaN
# 23         NaN              NaN        NaN              NaN         NaN
# 24         NaN              NaN        NaN              NaN         NaN
# 25         NaN              NaN        NaN              NaN         NaN
# 26         NaN              NaN        NaN              NaN         NaN
# 27         NaN              NaN        NaN              NaN         NaN
# 28         NaN              NaN        NaN              NaN         NaN
# 29         NaN              NaN        NaN              NaN         NaN
# ..         ...              ...        ...              ...         ...
# 73         NaN              NaN        NaN              NaN         NaN
# 74         NaN              NaN        NaN              NaN         NaN
# 75         NaN              NaN        NaN              NaN         NaN
# 76         NaN              NaN        NaN              NaN         NaN
# 77         NaN              NaN        NaN              NaN         NaN
# 78         NaN              NaN        NaN              NaN         NaN
# 79         NaN              NaN        NaN              NaN         NaN
# 80         NaN              NaN        NaN              NaN         NaN
# 81         NaN              NaN        NaN              NaN         NaN
# 82         NaN              NaN        NaN              NaN         NaN
# 83         NaN              NaN        NaN              NaN         NaN
# 84         NaN              NaN        NaN              NaN         NaN
# 85         NaN              NaN        NaN              NaN         NaN
# 86         NaN              NaN        NaN              NaN         NaN
# 87         NaN              NaN        NaN              NaN         NaN
# 88         NaN              NaN        NaN              NaN         NaN
# 89         NaN              NaN        NaN              NaN         NaN
# 90         NaN              NaN        NaN              NaN         NaN
# 91         NaN              NaN        NaN              NaN         NaN
# 92         NaN              NaN        NaN              NaN         NaN
# 93         NaN              NaN        NaN              NaN         NaN
# 94         NaN              NaN        NaN              NaN         NaN
# 95         NaN              NaN        NaN              NaN         NaN
# 96         NaN              NaN        NaN              NaN         NaN
# 97         NaN              NaN        NaN              NaN         NaN
# 98         NaN              NaN        NaN              NaN         NaN
# 99         NaN              NaN        NaN              NaN         NaN
# 100        NaN              NaN        NaN              NaN         NaN
# 101        NaN              NaN        NaN              NaN         NaN
# 102        NaN              NaN        NaN              NaN         NaN
#
#      Luminaire3 Count  Luminaire4  Luminaire4 Count  Luminaire5  \
# 0                 NaN         NaN               NaN         NaN
# 1                 NaN         NaN               NaN         NaN
# 2                 NaN         NaN               NaN         NaN
# 3                 NaN         NaN               NaN         NaN
# 4                 NaN         NaN               NaN         NaN
# 5                 NaN         NaN               NaN         NaN
# 6                 NaN         NaN               NaN         NaN
# 7                 NaN         NaN               NaN         NaN
# 8                 NaN         NaN               NaN         NaN
# 9                 NaN         NaN               NaN         NaN
# 10                NaN         NaN               NaN         NaN
# 11                NaN         NaN               NaN         NaN
# 12                NaN         NaN               NaN         NaN
# 13                NaN         NaN               NaN         NaN
# 14                NaN         NaN               NaN         NaN
# 15                NaN         NaN               NaN         NaN
# 16                NaN         NaN               NaN         NaN
# 17                NaN         NaN               NaN         NaN
# 18                NaN         NaN               NaN         NaN
# 19                NaN         NaN               NaN         NaN
# 20                NaN         NaN               NaN         NaN
# 21                NaN         NaN               NaN         NaN
# 22                NaN         NaN               NaN         NaN
# 23                NaN         NaN               NaN         NaN
# 24                NaN         NaN               NaN         NaN
# 25                NaN         NaN               NaN         NaN
# 26                NaN         NaN               NaN         NaN
# 27                NaN         NaN               NaN         NaN
# 28                NaN         NaN               NaN         NaN
# 29                NaN         NaN               NaN         NaN
# ..                ...         ...               ...         ...
# 73                NaN         NaN               NaN         NaN
# 74                NaN         NaN               NaN         NaN
# 75                NaN         NaN               NaN         NaN
# 76                NaN         NaN               NaN         NaN
# 77                NaN         NaN               NaN         NaN
# 78                NaN         NaN               NaN         NaN
# 79                NaN         NaN               NaN         NaN
# 80                NaN         NaN               NaN         NaN
# 81                NaN         NaN               NaN         NaN
# 82                NaN         NaN               NaN         NaN
# 83                NaN         NaN               NaN         NaN
# 84                NaN         NaN               NaN         NaN
# 85                NaN         NaN               NaN         NaN
# 86                NaN         NaN               NaN         NaN
# 87                NaN         NaN               NaN         NaN
# 88                NaN         NaN               NaN         NaN
# 89                NaN         NaN               NaN         NaN
# 90                NaN         NaN               NaN         NaN
# 91                NaN         NaN               NaN         NaN
# 92                NaN         NaN               NaN         NaN
# 93                NaN         NaN               NaN         NaN
# 94                NaN         NaN               NaN         NaN
# 95                NaN         NaN               NaN         NaN
# 96                NaN         NaN               NaN         NaN
# 97                NaN         NaN               NaN         NaN
# 98                NaN         NaN               NaN         NaN
# 99                NaN         NaN               NaN         NaN
# 100               NaN         NaN               NaN         NaN
# 101               NaN         NaN               NaN         NaN
# 102               NaN         NaN               NaN         NaN
#
#      Luminaire5 Count
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# ..                ...
# 73                NaN
# 74                NaN
# 75                NaN
# 76                NaN
# 77                NaN
# 78                NaN
# 79                NaN
# 80                NaN
# 81                NaN
# 82                NaN
# 83                NaN
# 84                NaN
# 85                NaN
# 86                NaN
# 87                NaN
# 88                NaN
# 89                NaN
# 90                NaN
# 91                NaN
# 92                NaN
# 93                NaN
# 94                NaN
# 95                NaN
# 96                NaN
# 97                NaN
# 98                NaN
# 99                NaN
# 100               NaN
# 101               NaN
# 102               NaN
#
# [103 rows x 26 columns]

# %%
lum_list = []

for lum in root.iter('Lum'):
    lamp = {}
    lamp['Luminaire Name'] = lum.find('Name').text
    lamp['Type'] = lum.find('LampType').text
    lamp['Power'] = float(lum.find('Pwr').text)
    lum_list.append(lamp)
        
lum_header = ['Luminaire Name', 'Type', 'Power']

lum_df = pd.DataFrame(lum_list, columns = lum_header)
lum_df
# Out:
# Empty DataFrame
# Columns: [Luminaire Name, Type, Power]
# Index: []

# %%
thrml_list = []

for thmlzn in root.iter('ThrmlZn'): 
    tzn = {}
    tzn['Zone Name'] = thmlzn.find('Name').text
    try:
        tzn['Zone Conditioning'] = thmlzn.find('Type').text
    except:
        tzn['Zone Conditioning'] = 'Conditioned'
    try:
        tzn['Ventilation Type'] = thmlzn.find('VentSrc').text
    except:
        tzn['Ventilation Type'] = 'Forced'
    try:
        tzn['Ventilation Control'] = thmlzn.find('VentCtrlMthd').text
    except:
        try:
            if thmlzn.find('VentSrc').text == 'None':
                pass
            else:
                tzn['Ventilation Control'] = 'Fixed'
        except:
            tzn['Ventilation Control'] = 'Fixed'
    try:
        tzn['Primary System'] = thmlzn.find('PriAirCondgSysRef[@index="0"]').text
    except:
        pass
    try:
        tzn['Secondary System'] = thmlzn.find('PriAirCondgSysRef[@index="1"]').text
    except:
        pass
    try:
        tzn['Ventilation System'] = thmlzn.find('VentSysRef').text
    except:
        try:
            if thmlzn.find('PriAirCondgSysRef[@index="0"]').text is not None or thmlzn.find('VentSrc').text != 'Natural':
                tzn['Ventilation System'] = thmlzn.find('PriAirCondgSysRef[@index="0"]').text
        except:
            pass
    try:
        tzn['Exhaust System'] = thmlzn.find('ExhSysRef').text
    except:
        pass
    thrml_list.append(tzn)

tzn_header = [
    'Zone Name', 'Zone Conditioning', 'Ventilation Type', 'Ventilation Control', 
    'Primary System', 'Secondary System', 'Ventilation System','Exhaust System'
]

tzn_df = pd.DataFrame(thrml_list, columns=tzn_header)
tzn_df
# Out:
#                   Zone Name Zone Conditioning Ventilation Type  \
# 0              VAV 101 Zone       Conditioned           Forced
# 1              VAV 102 Zone       Conditioned           Forced
# 2              VAV 103 Zone       Conditioned           Forced
# 3              VAV 104 Zone       Conditioned           Forced
# 4              VAV 105 Zone       Conditioned           Forced
# 5              VAV 106 Zone       Conditioned           Forced
# 6              VAV 107 Zone       Conditioned           Forced
# 7              VAV 108 Zone       Conditioned           Forced
# 8              VAV 109 Zone       Conditioned           Forced
# 9      VAV 110 111 112 Zone       Conditioned           Forced
# 10             VAV 113 Zone       Conditioned           Forced
# 11             VAV 114 Zone       Conditioned           Forced
# 12             VAV 115 Zone       Conditioned           Forced
# 13             VAV 116 Zone       Conditioned           Forced
# 14             VAV 117 Zone       Conditioned           Forced
# 15             VAV 118 Zone       Conditioned           Forced
# 16             VAV 119 Zone       Conditioned           Forced
# 17             VAV 120 Zone       Conditioned           Forced
# 18             VAV 121 Zone       Conditioned           Forced
# 19             VAV 122 Zone       Conditioned           Forced
# 20             VAV 123 Zone       Conditioned           Forced
# 21             VAV 124 Zone       Conditioned           Forced
# 22             VAV 125 Zone       Conditioned           Forced
# 23             VAV 126 Zone       Conditioned           Forced
# 24             VAV 127 Zone       Conditioned           Forced
# 25             VAV 128 Zone       Conditioned           Forced
# 26             VAV 129 Zone       Conditioned           Forced
# 27             VAV 130 Zone       Conditioned           Forced
# 28             VAV 131 Zone       Conditioned           Forced
# 29             VAV 132 Zone       Conditioned           Forced
# ..                      ...               ...              ...
# 73             VAV 312 Zone       Conditioned           Forced
# 74             VAV 313 Zone       Conditioned           Forced
# 75             VAV 314 Zone       Conditioned           Forced
# 76         VAV 315 317 Zone       Conditioned           Forced
# 77             VAV 316 Zone       Conditioned           Forced
# 78         VAV 318 319 Zone       Conditioned           Forced
# 79             VAV 320 Zone       Conditioned           Forced
# 80             VAV 321 Zone       Conditioned           Forced
# 81             VAV 322 Zone       Conditioned           Forced
# 82             LSV 301 Zone       Conditioned           Forced
# 83             LSV 302 Zone       Conditioned           Forced
# 84             LSV 303 Zone       Conditioned           Forced
# 85             LSV 304 Zone       Conditioned           Forced
# 86             LSV 305 Zone       Conditioned           Forced
# 87             LSV 306 Zone       Conditioned           Forced
# 88             LSV 307 Zone       Conditioned           Forced
# 89             LSV 308 Zone       Conditioned           Forced
# 90             FCU 1-2 Zone       Conditioned           Forced
# 91             FCU 1-3 Zone       Conditioned           Forced
# 92             FCU 1-1 Zone       Conditioned           Forced
# 93             FCU 1-4 Zone       Conditioned           Forced
# 94             FCU 1-5 Zone       Conditioned           Forced
# 95             FCU 1-6 Zone       Conditioned           Forced
# 96             FCU 2-1 Zone       Conditioned           Forced
# 97             FCU 2-2 Zone       Conditioned           Forced
# 98             FCU 3-1 Zone       Conditioned           Forced
# 99             FCU 3-2 Zone       Conditioned           Forced
# 100  UNCONDITIONED_1STFLOOR     Unconditioned             None
# 101  UNCONDITIONED_2NDFLOOR     Unconditioned             None
# 102  UNCONDITIONED_3RDFLOOR     Unconditioned             None
#
#     Ventilation Control Primary System  Secondary System Ventilation System  \
# 0                 Fixed        AHU-1/2               NaN            AHU-1/2
# 1                 Fixed        AHU-1/2               NaN            AHU-1/2
# 2                 Fixed        AHU-1/2               NaN            AHU-1/2
# 3                 Fixed        AHU-1/2               NaN            AHU-1/2
# 4                 Fixed        AHU-1/2               NaN            AHU-1/2
# 5                 Fixed        AHU-1/2               NaN            AHU-1/2
# 6                 Fixed        AHU-1/2               NaN            AHU-1/2
# 7            CO2Sensors        AHU-1/2               NaN            AHU-1/2
# 8                 Fixed        AHU-1/2               NaN            AHU-1/2
# 9                 Fixed        AHU-1/2               NaN            AHU-1/2
# 10                Fixed        AHU-1/2               NaN            AHU-1/2
# 11                Fixed        AHU-1/2               NaN            AHU-1/2
# 12           CO2Sensors        AHU-1/2               NaN            AHU-1/2
# 13           CO2Sensors        AHU-1/2               NaN            AHU-1/2
# 14           CO2Sensors        AHU-1/2               NaN            AHU-1/2
# 15           CO2Sensors        AHU-1/2               NaN            AHU-1/2
# 16                Fixed        AHU-1/2               NaN            AHU-1/2
# 17                Fixed        AHU-1/2               NaN            AHU-1/2
# 18                Fixed        AHU-1/2               NaN            AHU-1/2
# 19                Fixed        AHU-1/2               NaN            AHU-1/2
# 20                Fixed        AHU-1/2               NaN            AHU-1/2
# 21                Fixed        AHU-3/4               NaN            AHU-3/4
# 22                Fixed        AHU-3/4               NaN            AHU-3/4
# 23                Fixed        AHU-3/4               NaN            AHU-3/4
# 24                Fixed        AHU-3/4               NaN            AHU-3/4
# 25                Fixed        AHU-3/4               NaN            AHU-3/4
# 26                Fixed        AHU-3/4               NaN            AHU-3/4
# 27                Fixed        AHU-3/4               NaN            AHU-3/4
# 28                Fixed        AHU-3/4               NaN            AHU-3/4
# 29                Fixed        AHU-3/4               NaN            AHU-3/4
# ..                  ...            ...               ...                ...
# 73                Fixed        AHU-1/2               NaN            AHU-1/2
# 74                Fixed        AHU-1/2               NaN            AHU-1/2
# 75                Fixed        AHU-3/4               NaN            AHU-3/4
# 76                Fixed        AHU-3/4               NaN            AHU-3/4
# 77                Fixed        AHU-3/4               NaN            AHU-3/4
# 78                Fixed        AHU-3/4               NaN            AHU-3/4
# 79                Fixed        AHU-3/4               NaN            AHU-3/4
# 80                Fixed        AHU-1/2               NaN            AHU-1/2
# 81                Fixed        AHU-1/2               NaN            AHU-1/2
# 82                Fixed        AHU-1/2               NaN            AHU-1/2
# 83                Fixed        AHU-1/2               NaN            AHU-1/2
# 84                Fixed        AHU-1/2               NaN            AHU-1/2
# 85                Fixed        AHU-1/2               NaN            AHU-1/2
# 86                Fixed        AHU-1/2               NaN            AHU-1/2
# 87                Fixed        AHU-1/2               NaN            AHU-1/2
# 88                Fixed        AHU-3/4               NaN            AHU-3/4
# 89                Fixed        AHU-3/4               NaN            AHU-3/4
# 90                Fixed        FCU 1-2               NaN            FCU 1-2
# 91                Fixed        FCU 1-3               NaN            FCU 1-3
# 92                Fixed        FCU 1-1               NaN            FCU 1-1
# 93                Fixed        FCU 1-4               NaN            FCU 1-4
# 94                Fixed        FCU 1-5               NaN            FCU 1-5
# 95                Fixed        FCU 1-6               NaN            FCU 1-6
# 96                Fixed        FCU 2-1               NaN            FCU 2-1
# 97                Fixed        FCU 2-2               NaN            FCU 2-2
# 98                Fixed        FCU 3-1               NaN            FCU 3-1
# 99                Fixed        FCU 3-2               NaN            FCU 3-2
# 100                 NaN            NaN               NaN                NaN
# 101                 NaN            NaN               NaN                NaN
# 102                 NaN            NaN               NaN                NaN
#
#     Exhaust System
# 0              NaN
# 1              NaN
# 2              NaN
# 3         EF-1 2 3
# 4         EF-1 2 3
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10        EF-1 2 3
# 11        EF-1 2 3
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22        EF-1 2 3
# 23        EF-1 2 3
# 24        EF-1 2 3
# 25             NaN
# 26             NaN
# 27             NaN
# 28        EF-1 2 3
# 29             NaN
# ..             ...
# 73             NaN
# 74             NaN
# 75             NaN
# 76             NaN
# 77        EF-1 2 3
# 78             NaN
# 79             NaN
# 80             NaN
# 81             NaN
# 82        EF-1 2 3
# 83        EF-1 2 3
# 84        EF-1 2 3
# 85             NaN
# 86             NaN
# 87        EF-1 2 3
# 88        EF-1 2 3
# 89        EF-1 2 3
# 90             NaN
# 91             NaN
# 92             NaN
# 93             NaN
# 94             NaN
# 95            EF-4
# 96             NaN
# 97             NaN
# 98             NaN
# 99             NaN
# 100            NaN
# 101            NaN
# 102            NaN
#
# [103 rows x 8 columns]

# %%
CHW = []
CW = []
HHW = []
SHW = []

for fluid in root.iter('FluidSys'):
    
    # Chilled water system
    if fluid.find('Type').text == 'ChilledWater':      
        for Chlr in fluid.iter('Chlr'):
            chiller = {}
            chiller['Chiller Name'] = Chlr.find('Name').text
            try:
                chiller['Chiller Type'] = Chlr.find('Type').text
            except:
                chiller['Chiller Type'] = 'Screw'
            try:
                chiller['Condenser Type'] = Chlr.find('CndsrType').text
            except:
                chiller['Condenser Type'] = 'Air'
            try:
                chiller['Capacity (Btu)'] = float(Chlr.find('CapRtd').text)
            except:
                chiller['Capacity (Btu)'] = '~~~ MISSING ~~~'
            try:
                chiller['Efficiency (kW/Ton)'] = float(Chlr.find('KwPerTon').text)
            except:
                chiller['Efficiency (kW/Ton)'] = '~~~ MISSING ~~~'
            try:
                chiller['Efficiency (IPLV)'] = float(Chlr.find('IPLVKwPerTon').text)
            except:
                chiller['Efficiency (IPLV)'] = '~~~ MISSING ~~~'
            try:
                chiller['CHWS Temp'] = float(Chlr.getparent().find('DsgnSupWtrTemp').text)
            except:
                chiller['CHWS Temp'] = 44.0
            try:
                chiller['CHW Temp Diff'] = float(Chlr.getparent().find('DsgnSupWtrDelT').text)
            except:
                chiller['CHW Temp Diff'] = 20.0
            CHW.append(chiller)
                  
    # Condenser water system
    elif fluid.find('Type').text == 'CondenserWater':
        for ct in fluid.iter('HtRej'):
            tower = {}
            tower['Cooling Tower'] = ct.find('Name').text
            try:
                tower['Tower Type'] = ct.find('Type').text
            except:
                tower['Tower Type'] = 'OpenTower'
            try:
                tower['Fan Type'] = ct.find('Fan Type').text
            except:
                tower['Fan Type'] = 'Axial'
            try:
                tower['Capacity (Btu)'] = float(ct.find('CapRtd').text)
            except:
                tower['Capacity (Btu)'] = '~~~ MISSING ~~~'
            try:
                tower['Fan HP'] = float(ct.find('TotFanHP').text)
            except:
                tower['Fan HP'] = '~~~ MISSING ~~~'
            try:
                tower['Air Flow Rate'] = float(ct.find('AirFlowCap').text)
            except:
                tower['Air Flow Rate'] = '~~~ MISSING ~~~'
            try:
                tower['Water flow Rate'] = float(ct.find('WtrFlowCap').text)
            except:
                tower['Water Flow Rate'] = '~~~ MISSING ~~~'
            try:
                tower['CWS Temp'] = float(ct.getparent().find('DsgnSupWtrTemp').text)
            except:
                tower['CWS Temp'] = 81.8
            try:
                tower['CW Temp Diff'] = float(ct.getparent().find('DsgnSupWtrDelT').text)
            except:
                tower['CW Temp Diff'] = 10.0
            CW.append(tower)
                          
    # Heating hot water system
    elif fluid.find('Type').text == 'HotWater':
        for blr in fluid.iter('Blr'):
            boiler = {}
            boiler['Boiler Name'] = blr.find('Name').text
            try:
                boiler['Draft Type'] = blr.find('DraftType').text
            except:
                boiler['Draft Type'] = '~~~ MISSING ~~~'
            try:
                boiler['Capacity (Btu)'] = float(blr.find('CapRtd').text)
            except:
                boiler['Capacity (Btu)'] = '~~~ MISSING ~~~'
            try:
                boiler['AFUE'] = float(blr.find('AFUE').text)
            except:
                pass
            try:
                boiler['Combustion Efficiency'] = float(blr.find('CombEff').text)
            except:
                pass
            try:
                boiler['Thermal Efficiency'] = float(blr.find('ThrmlEff').text)
            except:
                pass
            try:
                boiler['HHWS Temp'] = float(blr.getparent().find('DsgnSupWtrTemp').text)
            except:
                boiler['HHWS Temp'] = 180.0
            try:
                boiler['HHW Temp Diff'] = float(blr.getparent().find('DsgnSupWtrDelT').text)
            except:
                boiler['HHW Temp Diff'] = 40.0
            HHW.append(boiler)
    
    # Service hot water system

CHW_header = [
    'Chiller Name', 'Chiller Type','Condenser Type', 'Capacity (Btu)', 
    'Efficiency (kW/Ton)', 'Efficiency (IPLV)', 'CHWS Temp', 'CHW Temp Diff'
]

CW_header = [
    'Cooling Tower', 'Tower Type', 'Fan Type', 'Capacity (Btu)', 'Fan HP', 
    'Air Flow Rate', 'Water flow Rate', 'CWS Temp', 'CW Temp Diff'
]

HHW_header = [
    'Boiler Name', 'Draft Type', 'Capacity (Btu)', 'AFUE', 
    'Combustion Efficiency', 'Thermal Efficiency', 'HHWS Temp','HHW Temp Diff'
]

CHW_df = pd.DataFrame(CHW, columns = CHW_header)
CW_df = pd.DataFrame(CW, columns = CW_header)
HHW_df = pd.DataFrame(HHW, columns = HHW_header)
display(CHW_df)
display(CW_df)
display(HHW_df)
# Out:
#           Chiller Name Chiller Type Condenser Type  Capacity (Btu)  \
# 0  WSHP-1 to 6 Cooling  Centrifugal          Fluid       5138400.0
#
#    Efficiency (kW/Ton)  Efficiency (IPLV)  CHWS Temp  CHW Temp Diff
# 0                 0.46               0.38       46.0           12.0
#              Cooling Tower Tower Type Fan Type  Capacity (Btu)  Fan HP  \
# 0  District Condenser Loop  OpenTower    Axial       5956620.0     0.0
#
#    Air Flow Rate  Water flow Rate  CWS Temp  CW Temp Diff
# 0        66053.0            952.7      82.0          12.5
#            Boiler Name  Draft Type  Capacity (Btu)  AFUE  \
# 0  WSHP-1 to 6 Heating  Condensing       5076000.0   NaN
#
#    Combustion Efficiency  Thermal Efficiency  HHWS Temp  HHW Temp Diff
# 0                    NaN                0.97      123.0           15.0

# %%
airsys_list = []
exhsys_list = []

for sys in root.iter('AirSys'):
    
    # For all systems except exhaust systems
    if sys.find('Type').text != 'Exhaust':
        ahu = {}
        
        # General air system inputs:
        ahu['Air System Name'] = sys.find('Name').text
        ahu['Type'] = sys.find('Type').text
        try:
            ahu['Cooling SAT'] = float(sys.find('ClgDsgnSupAirTemp').text)
        except:
            ahu['Cooling SAT'] = 55.0
        try:
            ahu['Heating SAT'] = float(sys.find('HtgDsgnSupAirTemp').text)
        except:
            ahu['Heating SAT'] = 90.0
        try:
            ahu['Economizer'] = sys.find('OACtrl/EconoCtrlMthd').text
        except:
            ahu['Economizer'] = 'No Economizer'
        try:
            ahu['Economizer Lockout'] = float(sys.find('OACtrl/EconoHiTempLockout').text)
        except:
            if ahu['Economizer'] == 'No Economizer':
                pass
            else:
                ahu['Economizer Lockout'] = 70.0
        
        # Coils and Fan Inputs
        for airseg in sys.iter('AirSeg'):
            if airseg.find('Type').text == 'Supply':
                
                # Cooling Coil
                if airseg.find('CoilClg') is not None:
                    try:
                        ahu['Cooling Coil Type'] = airseg.find('CoilClg/Type').text
                    except:
                        pass
                    cooling_cap = 0
                    try:
                        cooling_cap += float(airseg.find('CoilClg/CapTotNetRtd').text)
                    except:
                        try:
                            cooling_cap += float(airseg.find('CoilClg/CapTotGrossRtd').text)
                        except:
                            pass
                    ahu['Cooling Coil Capacity'] = cooling_cap
                    try:
                        ahu['DXSEER'] = float(airseg.find('CoilClg/DXSEER').text)
                    except:
                        pass
                    try:
                        ahu['DXEER'] = float(airseg.find('CoilClg/DXEER').text)
                    except:
                        pass

                # Heating Coil
                if airseg.find('CoilHtg') is not None:
                    ahu['Heating Coil Type'] = airseg.find('CoilHtg/Type').text
                    heating_cap = 0
                    try:
                        heating_cap += float(airseg.find('CoilHtg/CapTotNetRtd').text)
                    except:
                        try:
                            heating_cap += float(airseg.find('CoilHtg/CapTotGrossRtd').text)
                        except:
                            pass
                    ahu['Heating Coil Capacity'] = heating_cap
                    try:
                        ahu['Heat Pump COP'] = float(airseg.find('CoilHtg/HtPumpCOP').text)
                    except:
                        pass

                # Supply Fan
                if airseg.find('Fan') is not None:
                    try:
                        ahu['Supply Fan Control'] = airseg.find('Fan/CtrlMthd').text
                    except:
                        ahu['Supply Fan Control'] = 'ConstantVolume'
                    ahu['Supply Fan Flow'] = float(airseg.find('Fan/FlowCap').text)
                    try:
                        ahu['Supply Min. Flow'] = float(airseg.find('Fan/FlowMin').text)
                    except:
                        if ahu['Supply Fan Control'] == 'VariableSpeedDrive':
                            ahu['Supply Min. Flow'] = 0.0
                    try:
                        ahu['Supply Static Pressure'] = float(airseg.find('Fan/TotStaticPress').text)
                    except:
                        ahu['Supply Static Pressure'] = 0.5
                    try:
                        ahu['Supply Motor HP'] = float(airseg.find('Fan/MtrHP').text)
                    except:
                        ahu['Supply Motor HP'] = '~~~ MISSING ~~~'
                    try:
                        ahu['Supply Motor Eff'] = float(airseg.find('Fan/MtrEff').text)
                    except:
                        ahu['Supply Motor Eff'] = '~~~ MISSING ~~~'

            # Return/Relief Fan
            if airseg.find('Type').text in ['Return', 'Relief']:
                ahu['Return Air Type'] = airseg.find('Type').text
                
                if airseg.find('Fan') is not None:
                    try:
                        ahu['Return Fan Control'] = airseg.find('Fan/CtrlMthd').text
                    except:
                        ahu['Return Fan Control'] = 'ConstantVolume'
                    ahu['Return Fan Flow'] = float(airseg.find('Fan/FlowCap').text)
                    try:
                        ahu['Return Min. Flow'] = float(airseg.find('Fan/FlowMin').text)
                    except:
                        pass 
                    try:
                        ahu['Return Static Pressure'] = float(airseg.find('Fan/TotStaticPress').text)
                    except:
                        ahu['Return Static Pressure'] = 0.5
                    try:
                        ahu['Return Motor HP'] = float(airseg.find('Fan/MtrHP').text)
                    except:
                        ahu['Return Motor HP'] = '~~~ MISSING ~~~'
                    try:
                        ahu['Return Motor Eff'] = float(airseg.find('Fan/MtrEff').text)
                    except:
                        ahu['Return Motor Eff'] = '~~~ MISSING ~~~'
            
        
        
        # Heat Recovery Inputs
        if sys.find('HtRcvry') is not None:
            try:
                ahu['Heat Recovery Type'] = sys.find('HtRcvry/Type').text
            except:
                ahu['Heat Recovery Type'] = 'Plate'
            try:
                ahu['Heating Effectiveness'] = float(sys.find('HtRcvry/HtgSensEff100').text)
            except:
                ahu['Heating Effectiveness'] = 0.61
            try:
                ahu['Cooling Effectiveness'] = float(sys.find('HtRcvry/ClgSensEff100').text)
            except:
                ahu['Cooling Effectiveness'] = 0.59
            try:
                ahu['Heat Recovery Power'] = float(sys.find('HtRcvry/AuxPwr').text)
            except:
                ahu['Heat Recovery Power'] = 0.0

        airsys_list.append(ahu)
    
    elif sys.find('Type').text == 'Exhaust':
        exh_sys = {}
        exh_sys['Exhaust System Name'] = sys.find('Name').text
        exh_sys['Type'] = sys.find('Type').text
        exh_sys['Exhaust Type'] = sys.find('ExhSysType').text

        # Fan Inputs
        for exh in sys.iter('AirSeg'):
            exh_sys['Fan Name'] = exh.find('Fan/Name').text
            try:
                exh_sys['Control Method'] = exh.find('Fan/CtrlMthd').text
            except:
                exh_sys['Control Method'] = 'ConstantVolume'
            exh_sys['Flow Rate'] = float(exh.find('Fan/FlowCap').text)
            try:
                exh_sys['Min. Flow Rate'] = float(exh.find('Fan/FlowMin').text)
            except:
                pass       
            try:
                exh_sys['Static Pressure'] = float(exh.find('Fan/TotStaticPress').text)
            except:
                exh_sys['Static Pressure'] = 0.5
            try:
                exh_sys['Motor HP'] = float(exh.find('Fan/MtrHP').text)
            except:
                exh_sys['Motor HP'] = '~~~ MISSING ~~~'
            try:
                exh_sys['Motor Eff'] = float(exh.find('Fan/MtrEff').text)
            except:
                exh_sys['Motor Eff'] = '~~~ MISSING ~~~'
        
        exhsys_list.append(exh_sys)

ahu_header = [
    'Air System Name', 'Type','Cooling SAT','Heating SAT','Economizer','Economizer Lockout',
    'Cooling Coil Type','Cooling Coil Capacity','DXSEER','DXEER',
    'Heating Coil Type','Heating Coil Capacity','Heat Pump COP',
    'Supply Fan Control','Supply Fan Flow','Supply Min. Flow','Supply Static Pressure','Supply Motor HP','Supply Motor Eff',
    'Return Air Type','Return Fan Control','Return Fan Flow','Return Min. Flow','Return Static Pressure','Return Motor HP','Return Motor Eff',
    'Heat Recovery Type','Heating Effectiveness','Cooling Effectiveness','Heat Recovery Power'
]

exh_header = [
    'Exhaust System Name', 'Type', 'Exhaust Type', 'Fan Name', 'Control Method', 'Flow Rate','Min. Flow Rate', 'Static Pressure', 'Motor HP', 'Motor Eff'
]

ahu_df = pd.DataFrame(airsys_list, columns=ahu_header)
exh_df = pd.DataFrame(exhsys_list, columns=exh_header)
display(ahu_df)
display(exh_df)
# Out:
#   Air System Name Type  Cooling SAT  Heating SAT    Economizer  \
# 0         AHU-1/2  VAV         56.0         85.0  FixedDryBulb
# 1         AHU-3/4  VAV         56.0         85.0  FixedDryBulb
#
#    Economizer Lockout Cooling Coil Type  Cooling Coil Capacity  DXSEER  DXEER  \
# 0                70.0      ChilledWater              3702200.0     NaN    NaN
# 1                70.0      ChilledWater              1912800.0     NaN    NaN
#
#    ...  Return Fan Control  Return Fan Flow  Return Min. Flow  \
# 0  ...  VariableSpeedDrive          92000.0           10000.0
# 1  ...  VariableSpeedDrive          24000.0            8000.0
#
#   Return Static Pressure  Return Motor HP  Return Motor Eff  \
# 0                    1.0             25.0             0.936
# 1                    1.0              7.5             0.924
#
#    Heat Recovery Type  Heating Effectiveness  Cooling Effectiveness  \
# 0               Plate                   0.35                    0.2
# 1               Plate                   0.35                    0.2
#
#   Heat Recovery Power
# 0              4020.0
# 1              4020.0
#
# [2 rows x 30 columns]
#   Exhaust System Name     Type Exhaust Type      Fan Name      Control Method  \
# 0            EF-1 2 3  Exhaust   Laboratory  LabExhaust 1  VariableSpeedDrive
# 1                EF-4  Exhaust      General  LabExhaust 4  VariableSpeedDrive
#
#    Flow Rate  Min. Flow Rate  Static Pressure  Motor HP  Motor Eff
# 0    38000.0             0.0              2.0    20.000      0.930
# 1      200.0             0.0              0.5     0.083      0.855

# %%
trml_unit_list = []

# Only for uncontrolled or VAV boxes. No fan-powered boxes or active beams
for unit in root.iter('TrmlUnit'):
    trml = {}
    
    trml['Terminal Unit Name'] = unit.find('Name').text
    trml['Type'] = unit.find('Type').text
    trml['Assigned AHU'] = unit.getparent().find('Name').text
    trml['Zone Served'] = unit.find('ZnServedRef').text
    trml['Primary Flow'] = float(unit.find('PriAirFlowMax').text)
    try:
        trml['Primary Min. Flow'] = float(unit.find('PriAirFlowMin').text)
    except:
        pass
    
    if trml['Type'] == 'VAVReheatBox':
        try:
            trml['Heating Air Flow'] = float(unit.find('HtgAirFlowMax').text)
        except:
            pass
        try:
            trml['Reheat Coil Name'] = unit.find('CoilHtg/Name').text
        except:
            pass
        try:
            trml['Reheat Coil Type'] = unit.find('CoilHtg/Type').text
        except:
            pass
        heating_cap = 0
        try:
            heating_cap += float(unit.find('CoilHtg/CapTotNetRtd').text)
        except:
            try:
                heating_cap += float(unit.find('CoilHtg/CapTotGrossRtd').text)
            except:
                pass
        trml['Reheat Coil Capacity'] = heating_cap
    trml_unit_list.append(trml)
    
trml_header = [
    'Terminal Unit Name', 'Type', 'Assigned AHU', 'Zone Served', 
    'Primary Flow', 'Primary Min. Flow', 'Heating Air Flow', 
    'Reheat Coil Name', 'Reheat Coil Type', 'Reheat Coil Capacity'
]
    
trml_df = pd.DataFrame(trml_unit_list, columns=trml_header)
trml_df
# Out:
#    Terminal Unit Name          Type Assigned AHU           Zone Served  \
# 0             SAV 101  VAVReheatBox      AHU-1/2          VAV 101 Zone
# 1             SAV 102  VAVReheatBox      AHU-1/2          VAV 102 Zone
# 2             SAV 103  VAVReheatBox      AHU-1/2          VAV 103 Zone
# 3             SAV 104  VAVReheatBox      AHU-1/2          VAV 104 Zone
# 4             SAV 105  VAVReheatBox      AHU-1/2          VAV 105 Zone
# 5             SAV 106  VAVReheatBox      AHU-1/2          VAV 106 Zone
# 6             SAV 107  VAVReheatBox      AHU-1/2          VAV 107 Zone
# 7             SAV 108  VAVReheatBox      AHU-1/2          VAV 108 Zone
# 8             SAV 109  VAVReheatBox      AHU-1/2          VAV 109 Zone
# 9     SAV 110 111 112  VAVReheatBox      AHU-1/2  VAV 110 111 112 Zone
# 10            SAV 113  VAVReheatBox      AHU-1/2          VAV 113 Zone
# 11            SAV 114  VAVReheatBox      AHU-1/2          VAV 114 Zone
# 12            SAV 115  VAVReheatBox      AHU-1/2          VAV 115 Zone
# 13            SAV 116  VAVReheatBox      AHU-1/2          VAV 116 Zone
# 14            SAV 117  VAVReheatBox      AHU-1/2          VAV 117 Zone
# 15            SAV 118  VAVReheatBox      AHU-1/2          VAV 118 Zone
# 16            SAV 119  VAVReheatBox      AHU-1/2          VAV 119 Zone
# 17            SAV 120  VAVReheatBox      AHU-1/2          VAV 120 Zone
# 18            SAV 121  VAVReheatBox      AHU-1/2          VAV 121 Zone
# 19            SAV 122  VAVReheatBox      AHU-1/2          VAV 122 Zone
# 20            SAV 123  VAVReheatBox      AHU-1/2          VAV 123 Zone
# 21            SAV 133  VAVReheatBox      AHU-1/2          VAV 133 Zone
# 22            SAV 201  VAVReheatBox      AHU-1/2          VAV 201 Zone
# 23            SAV 202  VAVReheatBox      AHU-1/2          VAV 202 Zone
# 24            SAV 203  VAVReheatBox      AHU-1/2          VAV 203 Zone
# 25            SAV 204  VAVReheatBox      AHU-1/2          VAV 204 Zone
# 26            SAV 205  VAVReheatBox      AHU-1/2          VAV 205 Zone
# 27            SAV 206  VAVReheatBox      AHU-1/2          VAV 206 Zone
# 28            SAV 207  VAVReheatBox      AHU-1/2          VAV 207 Zone
# 29    SAV 208 209 210  VAVReheatBox      AHU-1/2  VAV 208 209 210 Zone
# ..                ...           ...          ...                   ...
# 60      LSV 306-1 2 3  VAVReheatBox      AHU-1/2          LSV 306 Zone
# 61            SAV 221  VAVReheatBox      AHU-1/2          VAV 221 Zone
# 62            SAV 231  VAVReheatBox      AHU-1/2          VAV 231 Zone
# 63            SAV 124  VAVReheatBox      AHU-3/4          VAV 124 Zone
# 64            SAV 125  VAVReheatBox      AHU-3/4          VAV 125 Zone
# 65            SAV 126  VAVReheatBox      AHU-3/4          VAV 126 Zone
# 66            SAV 127  VAVReheatBox      AHU-3/4          VAV 127 Zone
# 67            SAV 128  VAVReheatBox      AHU-3/4          VAV 128 Zone
# 68            SAV 129  VAVReheatBox      AHU-3/4          VAV 129 Zone
# 69            SAV 130  VAVReheatBox      AHU-3/4          VAV 130 Zone
# 70            SAV 131  VAVReheatBox      AHU-3/4          VAV 131 Zone
# 71            SAV 132  VAVReheatBox      AHU-3/4          VAV 132 Zone
# 72            SAV 134  VAVReheatBox      AHU-3/4          VAV 134 Zone
# 73          LSV 101-1  VAVReheatBox      AHU-3/4        LSV 101-1 Zone
# 74            SAV 222  VAVReheatBox      AHU-3/4          VAV 222 Zone
# 75            SAV 223  VAVReheatBox      AHU-3/4          VAV 223 Zone
# 76            SAV 224  VAVReheatBox      AHU-3/4          VAV 224 Zone
# 77            SAV 225  VAVReheatBox      AHU-3/4          VAV 225 Zone
# 78            SAV 226  VAVReheatBox      AHU-3/4          VAV 226 Zone
# 79            SAV 227  VAVReheatBox      AHU-3/4          VAV 227 Zone
# 80            SAV 228  VAVReheatBox      AHU-3/4          VAV 228 Zone
# 81            SAV 229  VAVReheatBox      AHU-3/4          VAV 229 Zone
# 82            SAV 230  VAVReheatBox      AHU-3/4          VAV 230 Zone
# 83            SAV 314  VAVReheatBox      AHU-3/4          VAV 314 Zone
# 84        SAV 315 317  VAVReheatBox      AHU-3/4      VAV 315 317 Zone
# 85            SAV 316  VAVReheatBox      AHU-3/4          VAV 316 Zone
# 86        SAV 318 319  VAVReheatBox      AHU-3/4      VAV 318 319 Zone
# 87            SAV 320  VAVReheatBox      AHU-3/4          VAV 320 Zone
# 88        LSV 307-1 2  VAVReheatBox      AHU-3/4          LSV 307 Zone
# 89        LSV 308-1 2  VAVReheatBox      AHU-3/4          LSV 308 Zone
#
#     Primary Flow  Primary Min. Flow  Heating Air Flow    Reheat Coil Name  \
# 0         1115.0              605.0             665.0          SAV 101 HC
# 1          300.0              260.0             260.0          SAV 102 HC
# 2           90.0               75.0              75.0          SAV 103 HC
# 3          740.0              275.0             275.0          SAV 104 HC
# 4          960.0              425.0             425.0          SAV 105 HC
# 5         1540.0             1285.0            1285.0          SAV 106 HC
# 6         1530.0              930.0            1050.0          SAV 107 HC
# 7         1495.0              875.0             655.0          SAV 108 HC
# 8           75.0               75.0              75.0          SAV 109 HC
# 9         3420.0             1815.0            1815.0  SAV 110 111 112 HC
# 10        1730.0              875.0             875.0          SAV 113 HC
# 11        1215.0              605.0             605.0          SAV 114 HC
# 12         655.0              405.0             405.0          SAV 115 HC
# 13         275.0              145.0             145.0          SAV 116 HC
# 14         180.0              105.0             105.0          SAV 117 HC
# 15         995.0              540.0             540.0          SAV 118 HC
# 16         120.0               75.0             120.0          SAV 119 HC
# 17         160.0               75.0              75.0          SAV 120 HC
# 18         115.0               75.0              75.0          SAV 121 HC
# 19        1515.0              605.0             605.0          SAV 122 HC
# 20         865.0              630.0             630.0          SAV 123 HC
# 21        1055.0              605.0             605.0          SAV 133 HC
# 22        1055.0              605.0             605.0          SAV 201 HC
# 23        1240.0              875.0             875.0          SAV 202 HC
# 24        1330.0              875.0             875.0          SAV 203 HC
# 25        1435.0              875.0             875.0          SAV 204 HC
# 26         820.0              630.0             630.0          SAV 205 HC
# 27        1420.0              875.0             875.0          SAV 206 HC
# 28         840.0              630.0             630.0          SAV 207 HC
# 29        2590.0             1000.0            1000.0  SAV 208 209 210 HC
# ..           ...                ...               ...                 ...
# 60        1095.0              600.0             600.0    LSV 306-1 2 3 HC
# 61         355.0              150.0             150.0          SAV 221 HC
# 62        1090.0              605.0             605.0          SAV 230 HC
# 63        1500.0              875.0             875.0          SAV 124 HC
# 64        1010.0              875.0             875.0          SAV 125 HC
# 65         565.0              275.0             275.0          SAV 126 HC
# 66        1995.0             1150.0            1150.0          SAV 127 HC
# 67         135.0               75.0              75.0          SAV 128 HC
# 68          75.0               75.0              75.0          SAV 129 HC
# 69         195.0              100.0             100.0          SAV 130 HC
# 70        2110.0             1150.0            1150.0          SAV 131 HC
# 71         835.0              605.0             605.0          SAV 132 HC
# 72        1385.0              875.0             875.0          SAV 134 HC
# 73        1505.0              840.0             840.0        LSV 101-1 HC
# 74        1640.0              605.0             605.0          SAV 222 HC
# 75        1925.0             1150.0            1150.0          SAV 223 HC
# 76        1085.0              630.0             630.0          SAV 224 HC
# 77        1085.0              605.0            1085.0          SAV 225 HC
# 78        1970.0             1150.0            1150.0          SAV 226 HC
# 79        1195.0              630.0             630.0          SAV 227 HC
# 80        2470.0             1150.0            1150.0          SAV 228 HC
# 81        1390.0              875.0             875.0          SAV 229 HC
# 82        1090.0              605.0             605.0        SAV 230 HC 2
# 83          75.0               75.0              75.0          SAV 314 HC
# 84        2380.0             1210.0            1210.0      SAV 315 317 HC
# 85        1695.0             1015.0            1015.0          SAV 316 HC
# 86        2435.0             1750.0            1750.0      SAV 318 319 HC
# 87         750.0              160.0             160.0          SAV 320 HC
# 88        3700.0              560.0             560.0        LSV 307-1 HC
# 89        3700.0              560.0             560.0        LSV 308-1 HC
#
#    Reheat Coil Type  Reheat Coil Capacity
# 0          HotWater               21500.0
# 1          HotWater                8400.0
# 2          HotWater                1500.0
# 3          HotWater                8900.0
# 4          HotWater               13800.0
# 5          HotWater               41600.0
# 6          HotWater               34000.0
# 7          HotWater               21200.0
# 8          HotWater                2400.0
# 9          HotWater               58800.0
# 10         HotWater               28400.0
# 11         HotWater               19600.0
# 12         HotWater               13100.0
# 13         HotWater                8900.0
# 14         HotWater                3400.0
# 15         HotWater               17500.0
# 16         HotWater                2400.0
# 17         HotWater                2400.0
# 18         HotWater                2400.0
# 19         HotWater               19600.0
# 20         HotWater               20400.0
# 21         HotWater               19600.0
# 22         HotWater               19600.0
# 23         HotWater               28400.0
# 24         HotWater               28400.0
# 25         HotWater               28400.0
# 26         HotWater               20400.0
# 27         HotWater               28400.0
# 28         HotWater               20400.0
# 29         HotWater               32500.0
# ..              ...                   ...
# 60         HotWater                1200.0
# 61         HotWater                4900.0
# 62         HotWater               19600.0
# 63         HotWater               28400.0
# 64         HotWater               28400.0
# 65         HotWater                8900.0
# 66         HotWater               37300.0
# 67         HotWater                2400.0
# 68         HotWater                2400.0
# 69         HotWater                3200.0
# 70         HotWater               37300.0
# 71         HotWater               19600.0
# 72         HotWater               28400.0
# 73         HotWater               27200.0
# 74         HotWater               19600.0
# 75         HotWater               37300.0
# 76         HotWater               20400.0
# 77         HotWater               19600.0
# 78         HotWater               37300.0
# 79         HotWater               20400.0
# 80         HotWater               37300.0
# 81         HotWater               28400.0
# 82         HotWater               19600.0
# 83         HotWater                2400.0
# 84         HotWater               39200.0
# 85         HotWater               32900.0
# 86         HotWater               56800.0
# 87         HotWater                5200.0
# 88         HotWater               19400.0
# 89         HotWater               19400.0
#
# [90 rows x 10 columns]

# %%
zone_sys_list = []
zone_exh_list = []

for znsys in root.iter('ZnSys'):
    
    # For zone air conditioning systems (does not work for baseboards or passive beams):
    if znsys.find('Type').text not in ['Exhaust', 'Baseboard', 'PassiveBeam']:
        zone_sys = {}
        
        # General Zone System Information
        zone_sys['Zone System Name'] = znsys.find('Name').text
        zone_sys['Type'] = znsys.find('Type').text
        zone_sys['Count'] = float(znsys.find('Cnt').text)
        zone_sys['Fan Control'] = znsys.find('FanCtrl').text
        try:
            zone_sys['Cooling SAT'] = float(znsys.find('ClgDsgnSupAirTemp').text)
        except:
            zone_sys['Cooling SAT'] = 55.0
        try:
            zone_sys['Heating SAT'] = float(znsys.find('HtgDsgnSupAirTemp').text)
        except:
            zone_sys['Heating SAT'] = 90.0
            
        # Cooling Coil Inputs
        zone_sys['Cooling Coil Name'] = znsys.find('CoilClg/Name').text
        zone_sys['Cooling Coil Type'] = znsys.find('CoilClg/Type').text
        cooling_cap = 0
        try:
            cooling_cap += float(znsys.find('CoilClg/CapTotNetRtd').text)
        except:
            try:
                cooling_cap += float(znsys.find('CoilClg/CapTotGrossRtd').text)
            except:
                pass
        zone_sys['Cooling Coil Capacity'] = cooling_cap
        try:
            zone_sys['DXSEER'] = float(znsys.find('CoilClg/DXSEER').text)
        except:
            pass
        try:
            zone_sys['DXEER'] = float(znsys.find('CoilClg/DXEER').text)
        except:
            pass
        
        # Heating Coil Inputs
        zone_sys['Heating Coil Name'] = znsys.find('CoilHtg/Name').text
        zone_sys['Heating Coil Type'] = znsys.find('CoilHtg/Type').text
        heating_cap = 0
        try:
            heating_cap += float(znsys.find('CoilHtg/CapTotNetRtd').text)
        except:
            try:
                heating_cap += float(znsys.find('CoilHtg/CapTotGrossRtd').text)
            except:
                pass
        zone_sys['Heating Coil Capacity'] = heating_cap
        try:
            zone_sys['Heat Pump COP'] = float(znsys.find('CoilHtg/HtPumpCOP').text)
        except:
            pass
        
        # Fan Inputs
        zone_sys['Fan Name'] = znsys.find('Fan/Name').text
        try:
            zone_sys['Control Method'] = znsys.find('Fan/CtrlMthd').text
        except:
            zone_sys['Control Method'] = 'ConstantVolume'
        zone_sys['Flow Rate'] = float(znsys.find('Fan/FlowCap').text)
        try:
            zone_sys['Min. Flow Rate'] = float(znsys.find('Fan/FlowMin').text)
        except:
            pass  
        try:
            zone_sys['Static Pressure'] = float(znsys.find('Fan/TotStaticPress').text)
        except:
            zone_sys['Static Pressure'] = 0.5
        try:
            zone_sys['Motor HP'] = float(znsys.find('Fan/MtrHP').text)
        except:
            zone_sys['Motor HP'] = '~~~ MISSING ~~~'
        try:
            zone_sys['Motor Eff'] = float(znsys.find('Fan/MtrEff').text)
        except:
            zone_sys['Motor Eff'] = '~~~ MISSING ~~~'
               
        zone_sys_list.append(zone_sys)
    
    # For zone exhaust systems
    elif znsys.find('Type').text == 'Exhaust':
        zone_exh = {}
        zone_exh['Zone Exhaust Name'] = znsys.find('Name').text
        zone_exh['Type'] = znsys.find('Type').text
        zone_exh['Exhaust Type'] = znsys.find('ExhSysType').text
        
        # Fan Inputs
        zone_exh['Fan Name'] = znsys.find('Fan/Name').text
        try:
            zone_exh['Control Method'] = znsys.find('Fan/CtrlMthd').text
        except:
            zone_exh['Control Method'] = 'ConstantVolume'
        zone_exh['Flow Rate'] = float(znsys.find('Fan/FlowCap').text)
        try:
            zone_exh['Min. Flow Rate'] = float(znsys.find('Fan/FlowMin').text)
        except:
            pass       
        try:
            zone_exh['Static Pressure'] = float(znsys.find('Fan/TotStaticPress').text)
        except:
            zone_exh['Static Pressure'] = 0.5
        try:
            zone_exh['Motor HP'] = float(znsys.find('Fan/MtrHP').text)
        except:
            zone_exh['Motor HP'] = '~~~ MISSING ~~~'
        try:
            zone_exh['Motor Eff'] = float(znsys.find('Fan/MtrEff').text)
        except:
            zone_exh['Motor Eff'] = '~~~ MISSING ~~~'
        
        zone_exh_list.append(zone_exh)
        
zs_header = [
    'Zone System Name', 'Type', 'Fan Control', 'Cooling SAT', 'Heating SAT', 'Count', 
    'Cooling Coil Name', 'Cooling Coil Type', 'Cooling Coil Capacity', 'DXSEER', 'DXEER',
    'Heating Coil Name', 'Heating Coil Type', 'Heating Coil Capacity', 'Heat Pump COP',
    'Fan Name', 'Control Method', 'Flow Rate','Min. Flow Rate', 'Static Pressure', 'Motor HP', 'Motor Eff'
]

ze_header = [
    'Zone Exhaust Name', 'Type', 'Exhaust Type', 'Fan Name', 'Control Method', 'Flow Rate','Min. Flow Rate', 'Static Pressure', 'Motor HP', 'Motor Eff'
]

zone_sys_df = pd.DataFrame(zone_sys_list, columns = zs_header)
zone_exh_df = pd.DataFrame(zone_exh_list, columns = ze_header)
display(zone_sys_df)
display(zone_exh_df)
# Out:
#   Zone System Name  Type Fan Control  Cooling SAT  Heating SAT  Count  \
# 0          FCU 1-1  FPFC  Continuous         57.0         90.0    1.0
# 1          FCU 1-2  FPFC  Continuous         56.0         90.0    1.0
# 2          FCU 1-3  FPFC  Continuous         63.8         90.0    1.0
# 3          FCU 1-4  FPFC  Continuous         56.0         90.0    1.0
# 4          FCU 1-5  FPFC  Continuous         56.0         90.0    1.0
# 5          FCU 1-6  FPFC  Continuous         59.4         90.0    1.0
# 6          FCU 2-1  FPFC  Continuous         57.0         90.0    1.0
# 7          FCU 2-2  FPFC  Continuous         63.4         90.0    1.0
# 8          FCU 3-1  FPFC  Continuous         57.0         90.0    1.0
# 9          FCU 3-2  FPFC  Continuous         56.8         90.0    1.0
#
#   Cooling Coil Name Cooling Coil Type  Cooling Coil Capacity  DXSEER  ...  \
# 0        FCU 1-1 CC      ChilledWater                20000.0     NaN  ...
# 1        FCU 1-2 CC      ChilledWater                12000.0     NaN  ...
# 2        FCU 1-3 CC      ChilledWater                26000.0     NaN  ...
# 3        FCU 1-4 CC      ChilledWater                12000.0     NaN  ...
# 4        FCU 1-5 CC      ChilledWater                12000.0     NaN  ...
# 5        FCU 1-6 CC      ChilledWater                32000.0     NaN  ...
# 6        FCU 2-1 CC      ChilledWater                20000.0     NaN  ...
# 7        FCU 2-2 CC      ChilledWater                24000.0     NaN  ...
# 8        FCU 3-1 CC      ChilledWater                20000.0     NaN  ...
# 9        FCU 3-2 CC      ChilledWater                33000.0     NaN  ...
#
#    Heating Coil Type Heating Coil Capacity Heat Pump COP     Fan Name  \
# 0           HotWater                   1.0           NaN  FCU 1-1 Fan
# 1           HotWater                   1.0           NaN  FCU 1-2 Fan
# 2           HotWater                   1.0           NaN  FCU 1-3 Fan
# 3           HotWater                   1.0           NaN  FCU 1-4 Fan
# 4           HotWater                   1.0           NaN  FCU 1-5 Fan
# 5           HotWater                   1.0           NaN  FCU 1-6 Fan
# 6           HotWater                   1.0           NaN  FCU 2-1 Fan
# 7           HotWater                   1.0           NaN  FCU 2-2 Fan
# 8           HotWater                   1.0           NaN  FCU 3-1 Fan
# 9           HotWater                   1.0           NaN  FCU 3-2 Fan
#
#    Control Method Flow Rate Min. Flow Rate  Static Pressure  Motor HP  \
# 0  ConstantVolume    1050.0            NaN             0.25     0.125
# 1  ConstantVolume     380.0            NaN             0.25     0.083
# 2  ConstantVolume    1125.0            NaN             0.25     0.250
# 3  ConstantVolume     380.0            NaN             0.25     0.083
# 4  ConstantVolume     380.0            NaN             0.25     0.083
# 5  ConstantVolume    1150.0            NaN             0.25     0.250
# 6  ConstantVolume    1050.0            NaN             0.25     0.125
# 7  ConstantVolume    1050.0            NaN             0.25     0.125
# 8  ConstantVolume    1050.0            NaN             0.25     0.125
# 9  ConstantVolume    1125.0            NaN             0.25     0.250
#
#    Motor Eff
# 0      0.855
# 1      0.855
# 2      0.855
# 3      0.855
# 4      0.855
# 5      0.855
# 6      0.855
# 7      0.855
# 8      0.855
# 9      0.855
#
# [10 rows x 22 columns]
# Empty DataFrame
# Columns: [Zone Exhaust Name, Type, Exhaust Type, Fan Name, Control Method, Flow Rate, Min. Flow Rate, Static Pressure, Motor HP, Motor Eff]
# Index: []

# %%
writer = pd.ExcelWriter(filename + ' - SpaceData.xlsx', engine='xlsxwriter')
space_df.to_excel(writer,sheet_name='Space Data')
lum_df.to_excel(writer,sheet_name='Luminaire Data')
tzn_df.to_excel(writer,sheet_name='Thermal Zone Data')
CHW_df.to_excel(writer,sheet_name='Fluid System Data')
CW_df.to_excel(writer,sheet_name='Fluid System Data', startrow=CHW_df.shape[0] + 4)
HHW_df.to_excel(writer,sheet_name='Fluid System Data', startrow=CHW_df.shape[0] + 4 + CW_df.shape[0] + 4)
ahu_df.to_excel(writer,sheet_name='Air System Data')
exh_df.to_excel(writer,sheet_name='Air System Data', startrow=ahu_df.shape[0] + 4)
trml_df.to_excel(writer,sheet_name='Terminal Units')
zone_sys_df.to_excel(writer,sheet_name='Zone System')
zone_exh_df.to_excel(writer,sheet_name='Zone System', startrow=zone_sys_df.shape[0] + 4)
writer.save()
